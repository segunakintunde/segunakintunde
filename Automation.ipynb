# %% [markdown]
# <a href="https://colab.research.google.com/github/segunakintunde/segunakintunde/blob/main/Automation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install selenium
# Out:
# Collecting selenium
#   Downloading selenium-4.33.0-py3-none-any.whl.metadata (7.5 kB)
# Requirement already satisfied: urllib3~=2.4.0 in /usr/local/lib/python3.11/dist-packages (from urllib3[socks]~=2.4.0->selenium) (2.4.0)
# Collecting trio~=0.30.0 (from selenium)
#   Downloading trio-0.30.0-py3-none-any.whl.metadata (8.5 kB)
# Collecting trio-websocket~=0.12.2 (from selenium)
#   Downloading trio_websocket-0.12.2-py3-none-any.whl.metadata (5.1 kB)
# Requirement already satisfied: certifi>=2025.4.26 in /usr/local/lib/python3.11/dist-packages (from selenium) (2025.4.26)
# Requirement already satisfied: typing_extensions~=4.13.2 in /usr/local/lib/python3.11/dist-packages (from selenium) (4.13.2)
# Requirement already satisfied: websocket-client~=1.8.0 in /usr/local/lib/python3.11/dist-packages (from selenium) (1.8.0)
# Requirement already satisfied: attrs>=23.2.0 in /usr/local/lib/python3.11/dist-packages (from trio~=0.30.0->selenium) (25.3.0)
# Requirement already satisfied: sortedcontainers in /usr/local/lib/python3.11/dist-packages (from trio~=0.30.0->selenium) (2.4.0)
# Requirement already satisfied: idna in /usr/local/lib/python3.11/dist-packages (from trio~=0.30.0->selenium) (3.10)
# Collecting outcome (from trio~=0.30.0->selenium)
#   Downloading outcome-1.3.0.post0-py2.py3-none-any.whl.metadata (2.6 kB)
# Requirement already satisfied: sniffio>=1.3.0 in /usr/local/lib/python3.11/dist-packages (from trio~=0.30.0->selenium) (1.3.1)
# Collecting wsproto>=0.14 (from trio-websocket~=0.12.2->selenium)
#   Downloading wsproto-1.2.0-py3-none-any.whl.metadata (5.6 kB)
# Requirement already satisfied: pysocks!=1.5.7,<2.0,>=1.5.6 in /usr/local/lib/python3.11/dist-packages (from urllib3[socks]~=2.4.0->selenium) (1.7.1)
# Requirement already satisfied: h11<1,>=0.9.0 in /usr/local/lib/python3.11/dist-packages (from wsproto>=0.14->trio-websocket~=0.12.2->selenium) (0.16.0)
# Downloading selenium-4.33.0-py3-none-any.whl (9.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.4/9.4 MB 30.9 MB/s eta 0:00:00
# Downloading trio-0.30.0-py3-none-any.whl (499 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 499.2/499.2 kB 11.2 MB/s eta 0:00:00
# Downloading trio_websocket-0.12.2-py3-none-any.whl (21 kB)
# Downloading outcome-1.3.0.post0-py2.py3-none-any.whl (10 kB)
# Downloading wsproto-1.2.0-py3-none-any.whl (24 kB)
# Installing collected packages: wsproto, outcome, trio, trio-websocket, selenium
# Successfully installed outcome-1.3.0.post0 selenium-4.33.0 trio-0.30.0 trio-websocket-0.12.2 wsproto-1.2.0

# %%
# !pip install robotframework
# Out:
# Collecting robotframework
#   Downloading robotframework-7.3-py3-none-any.whl.metadata (7.6 kB)
# Downloading robotframework-7.3-py3-none-any.whl (792 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 792.7/792.7 kB 8.8 MB/s eta 0:00:00
# Installing collected packages: robotframework
# Successfully installed robotframework-7.3

# %%
# !pip install robotframework-seleniumlibrary
# Out:
# Collecting robotframework-seleniumlibrary
#   Downloading robotframework_seleniumlibrary-6.7.1-py2.py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: selenium>=4.3.0 in /usr/local/lib/python3.11/dist-packages (from robotframework-seleniumlibrary) (4.33.0)
# Requirement already satisfied: robotframework>=4.1.3 in /usr/local/lib/python3.11/dist-packages (from robotframework-seleniumlibrary) (7.3)
# Collecting robotframework-pythonlibcore>=4.4.1 (from robotframework-seleniumlibrary)
#   Downloading robotframework_pythonlibcore-4.4.1-py2.py3-none-any.whl.metadata (9.0 kB)
# Requirement already satisfied: click>=8.0 in /usr/local/lib/python3.11/dist-packages (from robotframework-seleniumlibrary) (8.2.1)
# Requirement already satisfied: urllib3~=2.4.0 in /usr/local/lib/python3.11/dist-packages (from urllib3[socks]~=2.4.0->selenium>=4.3.0->robotframework-seleniumlibrary) (2.4.0)
# Requirement already satisfied: trio~=0.30.0 in /usr/local/lib/python3.11/dist-packages (from selenium>=4.3.0->robotframework-seleniumlibrary) (0.30.0)
# Requirement already satisfied: trio-websocket~=0.12.2 in /usr/local/lib/python3.11/dist-packages (from selenium>=4.3.0->robotframework-seleniumlibrary) (0.12.2)
# Requirement already satisfied: certifi>=2025.4.26 in /usr/local/lib/python3.11/dist-packages (from selenium>=4.3.0->robotframework-seleniumlibrary) (2025.4.26)
# Requirement already satisfied: typing_extensions~=4.13.2 in /usr/local/lib/python3.11/dist-packages (from selenium>=4.3.0->robotframework-seleniumlibrary) (4.13.2)
# Requirement already satisfied: websocket-client~=1.8.0 in /usr/local/lib/python3.11/dist-packages (from selenium>=4.3.0->robotframework-seleniumlibrary) (1.8.0)
# Requirement already satisfied: attrs>=23.2.0 in /usr/local/lib/python3.11/dist-packages (from trio~=0.30.0->selenium>=4.3.0->robotframework-seleniumlibrary) (25.3.0)
# Requirement already satisfied: sortedcontainers in /usr/local/lib/python3.11/dist-packages (from trio~=0.30.0->selenium>=4.3.0->robotframework-seleniumlibrary) (2.4.0)
# Requirement already satisfied: idna in /usr/local/lib/python3.11/dist-packages (from trio~=0.30.0->selenium>=4.3.0->robotframework-seleniumlibrary) (3.10)
# Requirement already satisfied: outcome in /usr/local/lib/python3.11/dist-packages (from trio~=0.30.0->selenium>=4.3.0->robotframework-seleniumlibrary) (1.3.0.post0)
# Requirement already satisfied: sniffio>=1.3.0 in /usr/local/lib/python3.11/dist-packages (from trio~=0.30.0->selenium>=4.3.0->robotframework-seleniumlibrary) (1.3.1)
# Requirement already satisfied: wsproto>=0.14 in /usr/local/lib/python3.11/dist-packages (from trio-websocket~=0.12.2->selenium>=4.3.0->robotframework-seleniumlibrary) (1.2.0)
# Requirement already satisfied: pysocks!=1.5.7,<2.0,>=1.5.6 in /usr/local/lib/python3.11/dist-packages (from urllib3[socks]~=2.4.0->selenium>=4.3.0->robotframework-seleniumlibrary) (1.7.1)
# Requirement already satisfied: h11<1,>=0.9.0 in /usr/local/lib/python3.11/dist-packages (from wsproto>=0.14->trio-websocket~=0.12.2->selenium>=4.3.0->robotframework-seleniumlibrary) (0.16.0)
# Downloading robotframework_seleniumlibrary-6.7.1-py2.py3-none-any.whl (104 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 104.7/104.7 kB 2.9 MB/s eta 0:00:00
# Downloading robotframework_pythonlibcore-4.4.1-py2.py3-none-any.whl (12 kB)
# Installing collected packages: robotframework-pythonlibcore, robotframework-seleniumlibrary
# Successfully installed robotframework-pythonlibcore-4.4.1 robotframework-seleniumlibrary-6.7.1

# %%
# !pip install robotframework-requests
# Out:
# Collecting robotframework-requests
#   Downloading robotframework_requests-0.9.7-py3-none-any.whl.metadata (7.2 kB)
# Requirement already satisfied: robotframework in /usr/local/lib/python3.11/dist-packages (from robotframework-requests) (7.3)
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (from robotframework-requests) (2.32.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests->robotframework-requests) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests->robotframework-requests) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests->robotframework-requests) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests->robotframework-requests) (2025.4.26)
# Downloading robotframework_requests-0.9.7-py3-none-any.whl (21 kB)
# Installing collected packages: robotframework-requests
# Successfully installed robotframework-requests-0.9.7

# %%
# Create a simple test file
# %%writefile test.robot
*** Settings ***
Library    SeleniumLibrary

*** Test Cases ***
Open Google
    Open Browser    https://www.google.com    Chrome
    Close Browser
# Out:
# Writing test.robot
